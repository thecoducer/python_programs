# %% [markdown]
# I'm a markdown text cell

# %%
# This is a code cell with data visualisation output
# %matplotlib inline
import matplotlib.pyplot as plt

time = [0, 1, 2, 3]
position = [0, 100, 200, 300]

plt.plot(time, position)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
# Out:
# Text(0, 0.5, 'Position (km)')

# %% [markdown]
# ## Image
# ![](https://raw.githubusercontent.com/thecoducer/python_programs/master/Images/code_happy.png)
